# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Operator Python”**
#
# **Disusun Oleh :**
#
# **Defran Naufalanski**
#
# **2611532020**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji beserta syukur saya panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga saya dapat menyelesaikan laporan praktikum mengenai pengenalan tipe data dan variabel Python yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan jenis - jenis yang terdapat pada bahasa pemrograman Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami secara mendalam konsep serta implementasi berbagai jenis operator dalam bahasa pemrograman Python mulai dari operator aritmatika, assignment, perbandingan, logika, membership dan identity, hingga bitwise. Di samping itu, kegiatan ini dapat mampu membantu penulis untuk mengolah data dan menyelesaikan berbagai permasalahan komputasi melalui program Python
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
# Defran Naufalanski

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam era digital dan perkembangan teknologi yang sangat pesat saat ini, bahasa pemrograman memegang peranan krusial dalam berbagai aspek pengembangan perangkat lunak, analisis data, serta kecerdasan buatan. Dari sekian banyak bahasa pemrograman yang ada, Python menjadi salah satu pilihan utama di kalangan akademisi maupun industri karena sintaksnya yang bersih, mudah dibaca, dan bersifat serbaguna. Keunggulan ini menjadikan Python sebagai fondasi yang ideal bagi pemula maupun profesional untuk mengeksplorasi konsep-konsep komputasi modern secara lebih mendalam dan efisien.
#
# Di dalam struktur dasar bahasa pemrograman Python, pengolahan data dan pembentukan logika alur program sangat bergantung pada komponen fundamental yang disebut sebagai operator. Operator berfungsi untuk menghubungkan nilai-nilai atau variabel serta memprosesnya agar menghasilkan nilai baru yang sesuai dengan kebutuhan sistem. Kompleksitas suatu program, mulai dari perhitungan matematis sederhana hingga pengambilan keputusan yang rumit, dibangun dari kombinasi berbagai jenis operator dasar yang terintegrasi dengan baik di dalam ekosistem bahasa Python.
#
# Secara lebih terperinci, operator dalam Python diklasifikasikan ke dalam beberapa kategori utama, masing-masing dengan fungsi spesifik yang mendukung manipulasi data yang berbeda. Operator aritmatika dan penugasan (assignment) menjadi fondasi utama dalam melakukan kalkulasi numerik dan penyimpanan nilai, sementara operator perbandingan dan logika memungkinkan program untuk melakukan evaluasi kondisi serta menentukan alur eksekusi yang dinamis. Selain itu, terdapat pula operator yang lebih spesifik seperti keanggotaan (membership) dan identitas (identity) untuk mengelola struktur data serta referensi memori, serta operator bitwise yang bekerja langsung pada level bit biner untuk pengolahan data tingkat rendah.
#
# Pemahaman teoritis mengenai jenis-jenis operator tersebut belum cukup jika tidak diimbangi dengan pengalaman praktik secara langsung melalui penulisan kode program. Implementasi nyata di lingkungan pengembangan memungkinkan seorang pengembang untuk mengenali potensi kesalahan sintaks, memahami perilaku tipe data, serta menguji ketepatan logika program yang dibuat. Oleh sebab itu, kegiatan praktikum ini dirancang sebagai sarana pembelajaran aktif guna menjembatani konsep teoretis pemrograman dengan kemampuan teknis aplikatif di lapangan.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami secara langsung konsep dan penggunaan berbagai jenis operator pada Python, seperti operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise. Selain itu, praktikum ini juga diharapkan dapat membantu penulis memahami penggunaan operator dalam mengolah data dan menyelesaikan suatu permasalahan melalui program Python.
#
# ## 1.2 Tujuan
# 1. Memahami dan mampu menerapkan konsep dasar penggunaan operator aritmatika untuk melakukan berbagai operasi perhitungan matematis dalam program Python.
# 2. Memahami dan mengimplementasikan operator penugasan (assignment) guna memberikan serta memperbarui nilai pada suatu variabel secara efisien.
# 3. Menguasai penggunaan operator perbandingan (comparison) untuk membandingkan dua nilai atau lebih guna menghasilkan nilai kebenaran (True atau False).
# 4. Mempelajari dan menggunakan operator logika untuk menggabungkan beberapa kondisi serta mengevaluasi alur keputusan di dalam program.
# 5. Memahami penggunaan operator keanggotaan (membership) dan operator identitas (identity) dalam memeriksa keberadaan elemen pada koleksi data serta membandingkan lokasi memori objek.
# 6. Mempraktikkan penggunaan operator bitwise untuk melakukan manipulasi data pada tingkat bit biner beserta konversinya.
# 7. Mampu mengintegrasikan berbagai jenis operator ke dalam rancangan kode program Python untuk mengolah data dan menyelesaikan permasalahan komputasi secara logis.
#
# ## 1.3 Manfaat
# 1. Memberikan pemahaman yang komprehensif bagi penulis mengenai konsep teoretis serta cara kerja berbagai jenis operator di dalam bahasa pemrograman Python.
# 2. Melatih keterampilan teknis penulis dalam mengetik, menyusun, dan mengeksekusi baris kode program untuk mengimplementasikan operator aritmatika, assignment, perbandingan, logika, membership, identity, hingga bitwise.   3. Mengembangkan kemampuan analitis dan berpikir logis dalam menyelesaikan permasalahan komputasi melalui pemilihan dan penggunaan operator yang tepat.
# 4. Menjadi sarana latihan praktis yang efektif dalam mengenali, mencegah, serta memperbaiki kesalahan sintaks maupun logika (debugging) saat membangun program Python sederhana.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Landasan Teori
#
# **2.1.1 Pengertian Operator**
#
# Di dalam bahasa pemrograman Python, operator adalah simbol-simbol khusus atau kata kunci yang digunakan untuk melakukan operasi tertentu terhadap satu, dua, atau lebih nilai (yang disebut sebagai operand). Operator memegang peranan krusial dalam menyusun logika alur program, melakukan perhitungan matematis, membandingkan data, hingga memanipulasi representasi biner di dalam memori komputer. Tanpa adanya operator, suatu program tidak akan mampu memproses data atau mengambil keputusan secara dinamis.
#
# **2.1.2 Operator Aritmatika**
#
# Operator aritmatika digunakan untuk melakukan operasi matematika dasar pada tipe data numerik. Di dalam Python, operator ini mencakup penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), sisa bagi/modulus (%), dan perpangkatan (**).
#
# **2.1.3 Operator Perbandingan (Comparison)**
#
# Operator perbandingan digunakan untuk membandingkan dua buah nilai atau variabel. Hasil dari operasi ini selalu berupa nilai boolean, yaitu True (benar) atau False (salah). Operator yang didukung meliputi sama dengan (==), tidak sama dengan (!=), lebih besar (>), lebih kecil (<), lebih besar atau sama dengan (>=), dan lebih kecil atau sama dengan (<=). Python juga mendukung perbandingan berantai (contoh: 0 < x < 100).
#
# **2.1.4 Operator Logika**
#
# Operator logika digunakan untuk menggabungkan beberapa kondisi atau ekspresi boolean. Tiga operator utama dalam Python adalah and (konjungsi, bernilai True jika semua kondisi True), or (disjungsi, bernilai True jika salah satu kondisi True), dan not (negasi untuk membalik nilai kebenaran).
#
# **2.1.5 Operator Penugasan (Assignment)**
#
# Operator penugasan digunakan untuk memberikan nilai ke dalam suatu variabel. Selain operator penugasan dasar (=), Python menyediakan operator penugasan gabungan (aritmatika dan penugasan sekaligus) seperti +=, -=, *=, /=, %=, //=, dan **=. Sebagai contoh, ekspresi x += 2 memiliki arti yang sama dengan x = x + 2.
#
# **2.1.6 Operator Keanggotaan (Membership)**
#
# Operator keanggotaan digunakan untuk memeriksa apakah suatu nilai atau elemen tertentu terdapat di dalam suatu koleksi data (seperti list, tuple, atau string). Operator ini terdiri dari in (bernilai True jika ada di dalam koleksi) dan not in (bernilai True jika tidak ada).
#
# **2.1.7 Operator Identitas (Identity)**
#
# Operator identitas digunakan untuk membandingkan lokasi memori dari dua objek. Operator ini menggunakan is (menghasilkan True jika kedua variabel merujuk pada objek yang sama di memori) dan is not (menghasilkan True jika merujuk pada objek yang berbeda). Perlu dicatat bahwa is membandingkan identitas memori, sedangkan == membandingkan isi atau nilai dari objek tersebut.
#
# **2.1.8 Operator Bitwise**
#
# Operator bitwise bekerja pada level bit atau representasi biner dari suatu angka. Operator ini mencakup AND (&), OR (|), XOR (^), NOT (~), geser kiri (<<), dan geser kanan (>>). Operator bitwise sering digunakan dalam pemrograman tingkat rendah, pemrograman sistem, atau optimasi komputasi tertentu.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Aritmatika_2611532020"

# %%
# Buat file dengan nama aritmatika_NIM.py
# Buat program untuk operator aritmatika dalam Python
# Nama variabel ditambah ] 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_2020 = int(input("Input angka-1: "))
angka2_2020 = int(input("Input angka-2: "))

# Penjumlahan
hasil_2020 = angka1_2020 + angka2_2020
print("\nOperator Penjumlahan")
print("Hasil:", hasil_2020)

# Pengurangan
hasil_2020 = angka1_2020 - angka2_2020   
print("\nOperator Pengurangan")
print("Hasil:", hasil_2020)

# Perkalian
hasil_2020 = angka1_2020 * angka2_2020
print("\nOperator Perkalian")
print("Hasil:", hasil_2020)

# Pembagian, pembagian bulat dan sisa bagi
if angka2_2020 != 0:
    hasil_2020 = angka1_2020 / angka2_2020
    print("\nOperator Pembagian")
    print("Hasil:", hasil_2020)

    hasil_2020 = angka1_2020 // angka2_2020
    print("\nOperator Pembagian Bulat")
    print("Hasil:", hasil_2020)

    hasil_2020 = angka1_2020 % angka2_2020
    print("\nOperator Sisa Bagi")
    print("Hasil:", hasil_2020)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil_2020 = angka1_2020 ** angka2_2020
print("\nOperator Pangkat")
print("Hasil:", hasil_2020)
# Out:
# Operator Penjumlahan
# Hasil: 22
#
# Operator Pengurangan
# Hasil: -2
#
# Operator Perkalian
# Hasil: 120
#
# Operator Pembagian
# Hasil: 0.8333333333333334
#
# Operator Pembagian Bulat
# Hasil: 0
#
# Operator Sisa Bagi
# Hasil: 10
#
# Operator Pangkat
# Hasil: 1000000000000

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 sampai 2 berfungsi untuk meminta pengguna memasukkan dua buah nilai angka melalui fungsi input() dan mengonversinya langsung ke tipe data integer ke dalam variabel angka1_2020 dan angka2_2020.
# 2. Baris 4 sampai 18 berfungsi untuk melakukan operasi aritmatika dasar berupa penjumlahan, pengurangan, dan perkalian, kemudian mencetak hasil perhitungannya ke layar.
# 3. Baris 20 sampai 31 berfungsi untuk memeriksa apakah angka kedua bukan nol, lalu melakukan operasi pembagian biasa (/), pembagian bulat (//), dan sisa bagi atau modulus (%), serta menangani pesan kesalahan jika angka kedua bernilai nol.
# 4. Baris 33 sampai 35 berfungsi untuk melakukan operasi perpangkatan (**) antara angka pertama dan angka kedua, lalu menampilkan hasil akhirnya ke layar.

# %% [markdown]
# ### 2.2.2 Program "Perbandingan_2611532020"

# %%
# Buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_2020 = int(input("Input angka-1: "))
angka2_2020 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_2020 = angka1_2020 > angka2_2020
print("\nOperator lebih besar dari")
print("angka1_2020 > angka2_2020 =", hasil_2020)

# Lebih kecil dari
hasil_2020 = angka1_2020 < angka2_2020
print("\nOperator lebih kecil dari")
print("angka1_2020 < angka2_2020 =", hasil_2020)

# Lebih besar dari atau sama dengan
hasil_2020 = angka1_2020 >= angka2_2020
print("\nOperator lebih besar dari atau sama dengan")
print("angka1_2020 >= angka2_2020 =", hasil_2020) 

# Lebih kecil dari atau sama dengan
hasil_2020 = angka1_2020 <= angka2_2020
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1_2020 <= angka2_2020 =", hasil_2020)

# Sama dengan
hasil_2020 = angka1_2020 == angka2_2020
print("\nOperator sama dengan")
print("angka1_2020 == angka2_2020 =", hasil_2020)

# Tidak sama dengan
hasil_2020 = angka1_2020 != angka2_2020
print("\nOperator tidak sama dengan")
print("angka1_2020 != angka2_2020 =", hasil_2020)

# Tambahan: perbandingan berantai dalam Python
hasil_2020 = 0 < angka1_2020 < 100
print("\nOperator perbandingan berantai")
print("0 < angka1_2020 < 100 =", hasil_2020)

hasil_2020 = 0 < angka2_2020 < 100
print("0 < angka2_2020 < 100 =", hasil_2020)
# Out:
# Operator lebih besar dari
# angka1_2020 > angka2_2020 = True
#
# Operator lebih kecil dari
# angka1_2020 < angka2_2020 = False
#
# Operator lebih besar dari atau sama dengan
# angka1_2020 >= angka2_2020 = True
#
# Operator lebih kecil dari atau sama dengan
# angka1_2020 <= angka2_2020 = False
#
# Operator sama dengan
# angka1_2020 == angka2_2020 = False
#
# Operator tidak sama dengan
# angka1_2020 != angka2_2020 = True
#
# Operator perbandingan berantai
# 0 < angka1_2020 < 100 = True
# 0 < angka2_2020 < 100 = True

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 sampai 2 berfungsi untuk meminta pengguna memasukkan dua nilai angka melalui fungsi input() dan mengonversinya ke dalam tipe data integer ke variabel angka1_2020 dan angka2_2020.
# 2. Baris 4 sampai 20 berfungsi untuk mengevaluasi dan menampilkan hasil perbandingan nilai menggunakan operator lebih besar dari (>), lebih kecil dari (<), lebih besar atau sama dengan (>=), serta lebih kecil atau sama dengan (<=).
# 3. Baris 22 sampai 31 berfungsi untuk mengevaluasi dan menampilkan hasil perbandingan kesamaan nilai menggunakan operator sama dengan (==) dan tidak sama dengan (!=).
# 4. Baris 33 sampai 40 berfungsi untuk melakukan dan menampilkan hasil perbandingan berantai (chained comparison) untuk memeriksa apakah nilai variabel berada di antara angka 0 dan 100.

# %% [markdown]
# ### 2.2.3 Program "Logika_2611532020"

# %%
# Buat file dengan nama logika_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: a1_1234
# Program ini menggunakan fungsi input()
# Program operator logika dalam Python

# Memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_2020 = input("Input nilai boolean-1 a1_2020 (true/false): ").strip().lower() == "true"
a2_2020 = input("Input nilai boolean-2 a2_2020 (true/false): ").strip().lower() == "true"

print("\nA1:", a1_2020)
print("A2:", a2_2020)

# Konjungsi: bernilai True jika keduanya True
hasil_2020 = a1_2020 and a2_2020
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_2020)

# Disjungsi: bernilai True jika salah satunya True
hasil_2020 = a1_2020 or a2_2020
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_2020)

# Negasi A1: membalik nilai A1
hasil_2020 = not a1_2020
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_2020)

# Negasi A2: membalik nilai A2
hasil_2020 = not a2_2020
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_2020)

# XOR: bernilai True jika kedua nilai berbeda
hasil_2020 = a1_2020 != a2_2020
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil_2020)
# Out:
# A1: True
# A2: False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = True
#
# Disjungsi Eksklusif (XOR)
# A1 XOR A2 = True

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 sampai 4 berfungsi untuk meminta pengguna memasukkan dua nilai boolean, membersihkan spasi, menyamakannya ke huruf kecil, lalu membandingkannya dengan teks "true" untuk disimpan ke dalam variabel a1_2020 dan a2_2020.
# 2. Baris 6 sampai 13 berfungsi untuk melakukan operasi konjungsi (and) serta menampilkan nilai dari masing-masing variabel boolean dan hasil logikanya ke layar.
# 3. Baris 15 sampai 25 berfungsi untuk mengevaluasi dan menampilkan hasil operasi disjungsi (or) serta negasi (not) pada masing-masing variabel.
# 4. Baris 27 sampai 30 berfungsi untuk melakukan operasi disjungsi eksklusif (xor) dengan memeriksa apakah kedua nilai boolean berbeda, lalu menampilkan hasil akhirnya ke layar.

# %% [markdown]
# ### 2.2.4 Program "Assignment_2611532020"

# %%
# Buat file dengan nama assignment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam Python

angka1_2020 = int(input("Input angka-1: "))
angka2_2020 = int(input("Input angka-2: "))

print("\nNilai awal angka1_2020 =", angka1_2020)
print("Nilai awal angka2_2020 =", angka2_2020)

# Assignment biasa
hasil_2020 = angka1_2020
print("\nAssignment Biasa (=)")
print("Hasil =", hasil_2020)

# Assignment penambahan
hasil_2020 = angka1_2020
hasil_2020 += angka2_2020
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_2020)

# Assignment pengurangan
hasil_2020 = angka1_2020
hasil_2020 -= angka2_2020
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_2020)

# Assignment perkalian
hasil_2020 = angka1_2020
hasil_2020 *= angka2_2020
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_2020)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_2020 != 0:
    hasil_2020 = angka1_2020
    hasil_2020 /= angka2_2020
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_2020)
    # Operator tambahan
    hasil_2020 = angka1_2020
    hasil_2020 //= angka2_2020
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_2020)
    hasil_2020 = angka1_2020
    hasil_2020 %= angka2_2020
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_2020)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assigment perpangkatan
hasil_2020 = angka1_2020
hasil_2020 **= angka2_2020
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_2020)
# Out:
# Nilai awal angka1_2020 = 20
# Nilai awal angka2_2020 = 10
#
# Assignment Biasa (=)
# Hasil = 20
#
# Assignment penambahan (+=)
# Hasil = 30
#
# Assignment pengurangan (-=)
# Hasil = 10
#
# Assignment perkalian (*=)
# Hasil = 200
#
# Assignment pembagian (/=)
# Hasil = 2.0
#
# Assignment pembagian bulat (//=)
# Hasil = 2
#
# Assignment sisa bagi (%=)
# Hasil = 0
#
# Assignment perpangkatan (**=)
# Hasil = 10240000000000

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 sampai 6 berfungsi untuk meminta pengguna memasukkan dua nilai angka melalui fungsi input(), mengonversinya ke tipe data integer ke variabel angka1_2020 dan angka2_2020, serta mencetak nilai awalnya ke layar.
# 2. Baris 8 sampai 23 berfungsi untuk melakukan operasi assignment biasa (=), penambahan (+=), dan pengurangan (-=), lalu menampilkan hasil perhitungannya.
# 3. Baris 25 sampai 46 berfungsi untuk memeriksa apakah angka kedua bukan nol, kemudian melakukan operasi assignment perkalian (*=), pembagian (/=), pembagian bulat (//=), dan sisa bagi (%=), serta menangani pesan kesalahan jika pembagi bernilai nol.
# 4. Baris 48 sampai 54 berfungsi untuk melakukan operasi assignment perpangkatan (**=) menggunakan nilai angka pertama dan kedua, lalu menampilkan hasil akhirnya ke layar.

# %% [markdown]
# ### 2.2.5 Program "Lainnya_2611532020"

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan identitas

print("==================================")
print("1. OPERATOR KEANGGOTAAN")
print("==================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_2020 = input("Masukkan beberapa data, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_2020 = [int(angka.strip()) for angka in input_data_2020.split(",")]

nilai_dicari_2020 = int(input("Masukkan nilai yang ingin dicari: "))

# Operator in
hasil_2020 = nilai_dicari_2020 in data_2020
print("\nOperator keanggotaan IN")
print(nilai_dicari_2020, "in", data_2020, "=", hasil_2020)

# Operator not in
hasil = nilai_dicari_2020 not in data_2020
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_2020, "not in", data_2020, "=", hasil_2020)


print("\n==================================")
print("2. OPERATOR IDENTITAS")
print("==================================")

# objek1 menggunakan list dari input pengguna
objek1_2020 = data_2020

# objek2 menggunakan list dari input pengguna
objek2_2020 = objek1_2020

# objek3 memiliki isi yang sama, tatpi merupakan objek yang baru
objek3_2020 = data_2020.copy()

print("objek1_2020:", objek1_2020)
print("objek2_2020:", objek2_2020)
print("objek3_2020:", objek3_2020)

# Operator is
hasil_2020 = objek1_2020 is objek2_2020
print("\nOperator identitas IS")
print("objek1_2020 is objek2_2020 =", hasil_2020)

# Operator is not
hasil_2020 = objek1_2020 is not objek3_2020
print("\nOperator identitas IS NOT")
print("objek1_2020 is not objek3_2020 =", hasil_2020)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1_2020 is objek3_2020 =", objek1_2020 is objek3_2020)
print("objek1_2020 == objek3_2020 =", objek1_2020 == objek3_2020)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
# Operator keanggotaan IN
# 5 in [15] = False
#
# Operator keanggotaan NOT IN
# 5 not in [15] = False
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1_2020: [15]
# objek2_2020: [15]
# objek3_2020: [15]
#
# Operator identitas IS
# objek1_2020 is objek2_2020 = True
#
# Operator identitas IS NOT
# objek1_2020 is not objek3_2020 = True
#
# Perbandingan identitas dan nilai
# objek1_2020 is objek3_2020 = False
# objek1_2020 == objek3_2020 = True

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 sampai 17 berfungsi untuk menampilkan judul operator keanggotaan, meminta pengguna memasukkan data berupa angka yang dipisahkan koma, mengonversinya ke dalam bentuk list integer, serta meminta nilai yang ingin dicari.
# 2. Baris 19 sampai 28 berfungsi untuk mengevaluasi dan menampilkan hasil pengecekan menggunakan operator keanggotaan in dan not in untuk memastikan keberadaan nilai di dalam list.
# 3. Baris 30 sampai 42 berfungsi untuk menampilkan judul operator identitas, serta menginisialisasi beberapa objek list (mereferensikan objek yang sama atau menduplikasi objek menggunakan fungsi .copy()).
# 4. Baris 44 sampai 52 berfungsi untuk mengevaluasi dan menampilkan hasil perbandingan identitas objek menggunakan operator is dan is not, serta membandingkan perbedaan antara identitas memori (is) dengan kesamaan nilai (==).

# %% [markdown]
# ### 2.2.6 Program "Bitwise_2611532020"

# %%
# Buat file  dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("\n==================================")
print("1. OPERATOR BITWISE")
print("==================================")

angka1_2020 = int(input("Masukkan angka bitwise-1: "))
angka2_2020 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1_2020 =", angka1_2020, "| biner =", bin(angka1_2020))
print("angka2_2020 =", angka2_2020, "| biner =", bin(angka2_2020))

# Bitwise AND
hasil_2020 = angka1_2020 & angka2_2020
print("\nBitwise AND (&)")
print(angka1_2020, "&", angka2_2020, "=", hasil_2020)
print("Biner hasil =", bin(hasil_2020))
print("Biner hasil (8 bit) =", format(hasil_2020, "08b"))

# Bitwise Or
hasil_2020 = angka1_2020 | angka2_2020
print("\nBitwise OR (|)")
print(angka1_2020, "|", angka2_2020, "=", hasil_2020)
print("Biner hasil =", bin(hasil_2020))
print("Biner hasil (8 bit) =", format(hasil_2020, "08b"))

# Bitwise XOR
hasil_2020 = angka1_2020 ^ angka2_2020
print("\nBitwise XOR (^)")
print(angka1_2020, "^", angka2_2020, "=", hasil_2020)
print("Biner hasil =", bin(hasil_2020))
print("Biner hasil (8 bit) =", format(hasil_2020, "08b"))

# Bitwise NOT
hasil_2020 = ~angka1_2020
print("\nBitwise NOT (~)")
print("~", angka1_2020, "=", hasil_2020)
print("Biner hasil =", bin(hasil_2020))
print("Biner hasil (8 bit) =", format(hasil_2020, "08b"))

# Bitwise geser kiri
jumlah_geser_2020 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_2020 = angka1_2020 << jumlah_geser_2020
print("\nBitwise geser kiri (<<)")
print(angka1_2020, "<<", jumlah_geser_2020, "=", hasil_2020)
print("Biner hasil =", bin(hasil_2020))
print("Biner hasil (8 bit) =", format(hasil_2020, "08b"))

# Bitwise geser kanan
hasil_2020 = angka1_2020 >> jumlah_geser_2020
print("\nBitwise geser kiri (>>)")
print(angka1_2020, ">>", jumlah_geser_2020, "=", hasil_2020)
print("Biner hasil =", bin(hasil_2020))
print("Biner hasil (8 bit) =", format(hasil_2020, "08b"))
# Out:
# ...
# 1. OPERATOR BITWISE
# ...
# Angka dalam bentuk desimal dan biner
# angka1_2020 = 6 | biner = 0b110
# angka2_2020 = 7 | biner = 0b111
#
# Bitwise AND (&)
# 6 & 7 = 6
# Biner hasil = 0b110
# Biner hasil (8 bit) = 00000110
#
# Bitwise OR (|)
# 6 | 7 = 7
# Biner hasil = 0b111
# Biner hasil (8 bit) = 00000111
#
# Bitwise XOR (^)
# 6 ^ 7 = 1
# Biner hasil = 0b1
# Biner hasil (8 bit) = 00000001
#
# Bitwise NOT (~)
# ~ 6 = -7
# Biner hasil = -0b111
# Biner hasil (8 bit) = -0000111
#
# Bitwise geser kiri (<<)
# 6 << 2 = 24
# Biner hasil = 0b11000
# Biner hasil (8 bit) = 00011000
#
# Bitwise geser kiri (>>)
# 6 >> 2 = 1
# Biner hasil = 0b1
# Biner hasil (8 bit) = 00000001

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 sampai 12 berfungsi untuk menampilkan judul operator bitwise, meminta pengguna memasukkan dua nilai angka melalui fungsi input(), mengonversinya ke tipe data integer, serta menampilkan bentuk desimal dan representasi binernya menggunakan fungsi bin().
# 2. Baris 14 sampai 35 berfungsi untuk melakukan operasi bitwise AND (&), OR (|), dan XOR (^), lalu mencetak hasil perhitungan beserta format binernya dalam bentuk standar maupun format 8-bit (08b).
# 3. Baris 37 sampai 43 berfungsi untuk melakukan operasi bitwise NOT (~) pada angka pertama dan menampilkan hasil serta representasi binernya.
# 4. Baris 45 sampai 54 berfungsi untuk meminta jumlah pergeseran bit, lalu menjalankan operasi bitwise geser kiri (<<) dan geser kanan (>>) serta menampilkan hasil akhirnya ke layar.

# %% [markdown]
# # Tugas Praktikum
#
# Soal:
#
# <div align="center">
# <img src="images/soal.png" width="400"><br>
# <em>Gambar 2.3 : Soal Tugas Praktikum</em>
# </div>
#
# Kode Jawaban :
#
# a. Kode Program "Tugas3_2611532020"

# %%
print("=== SISTEM TRANSAKSI TOKO ===")

nama_2020 = input("Masukkan Nama Pelanggan : ")
status_2020 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_2020 = float(input("Masukkan Total Belanja : Rp"))
jumlah_barang_2020 = int(input("Masukkan Jumlah Barang : "))
kode_promo_2020 = input("Masukkan Kode Promo : ").upper()

syarat_belanja_2020 = total_belanja_2020 >= 200000
syarat_barang_2020 = jumlah_barang_2020 >= 3
status_member_2020 = status_2020 == "member"

daftar_promo_2020 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

promo_tersedia_2020 = kode_promo_2020 in daftar_promo_2020
promo_tidak_tersedia_2020 = kode_promo_2020 not in daftar_promo_2020

diskon_member_2020 = status_member_2020 and syarat_belanja_2020

promo_didapatkan_2020 = promo_tersedia_2020 and (syarat_belanja_2020 or syarat_barang_2020)

bukan_member_2020 = not status_member_2020

if diskon_member_2020:
    persentase_diskon_2020 = 0.10
else:
    persentase_diskon_2020 = 0.05 if syarat_belanja_2020 else 0

besar_diskon_2020 = total_belanja_2020 * persentase_diskon_2020

total_pembayaran_2020 = total_belanja_2020 - besar_diskon_2020

if jumlah_barang_2020 > 0:
    rata_rata_barang_2020 = total_belanja_2020 / jumlah_barang_2020
else:
    rata_rata_barang_2020 = 0

sisa_pembagian_2020 = int(total_belanja_2020) % jumlah_barang_2020 if jumlah_barang_2020 > 0 else 0


poin_2020 = 0
if status_member_2020:
    poin_2020 += int(total_pembayaran_2020 // 10000)

jumlah_barang_tersisa_2020 = jumlah_barang_2020
if promo_didapatkan_2020:
    jumlah_barang_tersisa_2020 -= 1

kode_1_2020 = ["HEMAT10"]
kode_2_2020 = ["HEMAT10"]

nilai_sama_2020 = kode_1_2020 == kode_2_2020
objek_sama_2020 = kode_1_2020 is kode_2_2020
objek_berbeda_2020 = kode_1_2020 is not kode_2_2020


kode_member_2020 = 1 if status_member_2020 else 0
kode_belanja_2020 = 2 if syarat_belanja_2020 else 0
kode_barang_2020 = 4 if syarat_barang_2020 else 0
kode_promo_2020 = 8 if promo_tersedia_2020 else 0

# Operator OR (|)
kode_status_2020 = (
    kode_member_2020
    | kode_belanja_2020
    | kode_barang_2020
    | kode_promo_2020
)

cek_member_2020 = kode_status_2020 & 1
cek_belanja_2020 = kode_status_2020 & 2
cek_barang_2020 = kode_status_2020 & 4
cek_promo_2020 = kode_status_2020 & 8

kode_referensi_2020 = 11
perbandingan_status_2020 = kode_status_2020 ^ kode_referensi_2020

kode_shift_2020 = kode_status_2020 << 1


member_access_2020 = bool(cek_member_2020)
promo_access_2020 = bool(cek_promo_2020)
free_shipping_access_2020 = syarat_belanja_2020 and syarat_barang_2020


print("\n=== DATA PELANGGAN ===")
print("Nama Pelanggan       :", nama_2020)
print("Status Pelanggan     :", status_2020)
print("Total Belanja        : Rp", total_belanja_2020)
print("Jumlah Barang        :", jumlah_barang_2020)
print("Kode Promo           :", kode_promo_2020)


print("\n=== HASIL VALIDASI ===")
print("Belanja >= Rp200000  :", syarat_belanja_2020)
print("Jumlah Barang >= 3   :", syarat_barang_2020)
print("Status Member        :", status_member_2020)
print("Kode Promo Tersedia  :", promo_tersedia_2020)
print("Mendapatkan Diskon   :", diskon_member_2020)
print("Mendapatkan Promo    :", promo_didapatkan_2020)


print("\n=== HASIL PERHITUNGAN ===")
print("Besarnya Diskon      : Rp", besar_diskon_2020)
print("Total Pembayaran     : Rp", total_pembayaran_2020)
print("Rata-rata Harga      : Rp", rata_rata_barang_2020)
print("Sisa Pembagian       :", sisa_pembagian_2020)


print("\n=== HAK AKSES PELANGGAN ===")
print("Kode Hak Akses       :", format(kode_status_2020, "04b"))
print("Member Access        :", member_access_2020)
print("Promo Access         :", promo_access_2020)
print("Free Shipping Access :", free_shipping_access_2020)
print("Poin Pelanggan       :", poin_2020)


print("\n=== OPERATOR IDENTITAS ===")
print("kode_1 == kode_2     :", nilai_sama_2020)
print("kode_1 is kode_2     :", objek_sama_2020)
print("kode_1 is not kode_2 :", objek_berbeda_2020)


print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print("0001 | 0010 | 0100 | 1000")

print("Kode Biner           :", format(kode_status_2020, "04b"))
print("Kode Desimal         :", kode_status_2020)

print("\n=== PEMERIKSAAN STATUS ===")

print("\nCek Member")
print(format(kode_status_2020, "04b"), "& 0001")
print("Hasil Biner         :", format(cek_member_2020, "04b"))
print("Hasil Desimal       :", cek_member_2020)

print("\nCek Belanja")
print(format(kode_status_2020, "04b"), "& 0010")
print("Hasil Biner         :", format(cek_belanja_2020, "04b"))
print("Hasil Desimal       :", cek_belanja_2020)

print("\nCek Jumlah Barang")
print(format(kode_status_2020, "04b"), "& 0100")
print("Hasil Biner         :", format(cek_barang_2020, "04b"))
print("Hasil Desimal       :", cek_barang_2020)

print("\nCek Promo")
print(format(kode_status_2020, "04b"), "& 1000")
print("Hasil Biner         :", format(cek_promo_2020, "04b"))
print("Hasil Desimal       :", cek_promo_2020)

print("\n=== PERBANDINGAN STATUS (XOR) ===")
print("Kode Transaksi      :", format(kode_status_2020, "04b"))
print("Kode Referensi      :", format(kode_referensi_2020, "04b"))
print(format(kode_status_2020, "04b"), "^",
      format(kode_referensi_2020, "04b"))
print("Hasil Biner         :", format(perbandingan_status_2020, "04b"))
print("Hasil Desimal       :", perbandingan_status_2020)

print("\n=== SHIFT ===")
print(format(kode_status_2020, "04b"), "<< 1")
print("Hasil Biner         :", format(kode_shift_2020, "b"))
print("Hasil Desimal       :", kode_shift_2020)

print("\n=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
# === DATA PELANGGAN ===
# Nama Pelanggan       : Defran
# Status Pelanggan     : member
# Total Belanja        : Rp 200000.0
# Jumlah Barang        : 5
# Kode Promo           : 8
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000  : True
# Jumlah Barang >= 3   : True
# Status Member        : True
# Kode Promo Tersedia  : True
# Mendapatkan Diskon   : True
# Mendapatkan Promo    : True
#
# === HASIL PERHITUNGAN ===
# Besarnya Diskon      : Rp 20000.0
# Total Pembayaran     : Rp 180000.0
# Rata-rata Harga      : Rp 40000.0
# Sisa Pembagian       : 0
#
# === HAK AKSES PELANGGAN ===
# Kode Hak Akses       : 1111
# Member Access        : True
# Promo Access         : True
# Free Shipping Access : True
# Poin Pelanggan       : 18
#
# === OPERATOR IDENTITAS ===
# kode_1 == kode_2     : True
# kode_1 is kode_2     : False
# kode_1 is not kode_2 : True
#
# === OPERASI BITWISE ===
# === Kode Status Transaksi ===
# 0001 | 0010 | 0100 | 1000
# ...

# %% [markdown]
# **Penjelasan/Analisis :**
#
# <div align="center">
# <img src="images/analisis.png" width="400"><br>
# <em>Gambar 2.3 : Soal Analisis Tugas Praktikum</em>
# </div>
#
# **1. Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.**
#
# Operator aritmatika yang digunakan dalam program ini meliputi perkalian (*), pengurangan (-), pembagian (/), pembagian bulat (//), dan modulus (%). Operator perkalian digunakan untuk menghitung nominal potongan diskon berdasarkan persentase, sedangkan pengurangan dipakai untuk menghitung total pembayaran akhir setelah dipotong diskon. Selain itu, pembagian digunakan untuk mencari rata-rata harga barang per satuan, pembagian bulat dimanfaatkan untuk menghitung perolehan poin member berdasarkan kelipatan total pembayaran, dan modulus menghitung sisa bagi dari total belanja terhadap jumlah barang.
#
# **2. Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.**
#
# Operator and diterapkan untuk memastikan diskon khusus hanya diberikan jika seluruh syarat terpenuhi secara bersamaan (status member dan total belanja minimal tercapai). Operator or digunakan agar promo tetap didapat jika salah satu dari syarat terpenuhi (total belanja memenuhi atau jumlah barang mencukupi). Sementara itu, operator not digunakan untuk membalik nilai kebenaran status keanggotaan guna keperluan validasi data.
#
# **3. Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.**
#
# Operator in berfungsi untuk memeriksa apakah kode promo yang diinputkan oleh pengguna benar-benar terdaftar di dalam list koleksi data daftar promo yang tersedia, yang akan bernilai benar jika kodenya valid. Sebaliknya, operator not in berfungsi untuk memastikan apakah suatu kode promo tidak terdapat di dalam daftar tersebut.
#
# **4. Apa perbedaan antara is dan == pada Python?**
#
# Perbedaan utamanya adalah operator == membandingkan nilai atau isi dari dua objek, sedangkan operator is membandingkan identitas atau lokasi penyimpanan objek tersebut di dalam memori komputer.
#
# **5. Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.**
#
# Operator bitwise menggunakan operator OR (|) untuk menggabungkan berbagai status hak akses terpisah (seperti member, syarat belanja, jumlah barang, dan promo) ke dalam satu variabel numerik terpadu. Untuk membaca kembali status tersebut, program menggunakan operator AND (&) dengan angka masking tertentu guna menyaring bit spesifik, serta menggunakan operator XOR (^) dan geser bit (<<) untuk manipulasi lanjutan.
#
# **6. Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.**
#
# Alur program bermula dari pengambilan input data pelanggan, total belanja, jumlah barang, dan kode promo. Data tersebut kemudian divalidasi menggunakan operator perbandingan dan logika untuk mengecek batas nominal belanja serta ketersediaan promo. Berdasarkan hasil validasi tersebut, struktur percabangan menentukan persentase diskon, mengalikannya dengan total belanja untuk mendapatkan besar diskon, lalu mengurikannya dari total belanja awal untuk menghasilkan total pembayaran sekaligus menentukan status perolehan promo.
#
# **7. Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.**
#
# Kondisi yang menghasilkan True terdapat pada syarat_belanja_2020 = total_belanja_2020 >= 200000 ketika total belanja mencapai atau melebihi Rp200.000. Sebaliknya, kondisi yang menghasilkan False terdapat pada objek_sama_2020 = kode_1_2020 is kode_2_2020 karena meskipun isi listnya sama, keduanya berada di lokasi memori yang berbeda.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa penggunaan berbagai jenis operator pada Python mulai dari operator aritmatika, assignment, perbandingan, logika, membership, identity, hingga bitwise memiliki peran yang sangat fundamental dalam memproses data dan mengeksekusi instruksi komputasi secara tepat. Setiap operator dirancang dengan fungsi spesifik, seperti melakukan kalkulasi numerik, mengevaluasi kondisi boolean, hingga memanipulasi data pada tingkat biner, yang terbukti sangat membantu penulis dalam merancang serta mengimplementasikan alur logika program sederhana secara efektif.
#
# Dalam konteks pengembangan program, penguasaan terhadap konsep operator ini memanfaatkan keunggulan sintaks Python yang fleksibel dan mudah dibaca, sehingga proses pengolahan data, pemeriksaan koleksi elemen, serta pengelolaan referensi objek memori dapat dilakukan secara efisien. Pemahaman yang mendalam mengenai karakteristik dan aturan penggunaan masing-masing operator tidak hanya memudahkan penulis dalam menyelesaikan berbagai permasalahan komputasi selama praktikum, tetapi juga menjadi fondasi yang kuat untuk membangun algoritma pemrograman yang lebih kompleks di masa mendatang.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] G. Rossum, "Python Tutorial," Python Software Foundation, [Online]. Tersedia: https://docs.python.org/3/tutorial/index.html [Diakses: 18 Sep. 2026].
#
# [2] M. Lutz, Learning Python, 5th ed. O'Reilly Media, 2013. [Online]. Tersedia: https://www.oreilly.com/library/view/learning-python-5th-edition/9781449355736/ [Diakses: 18 Sep. 2026].
#
# [3] J. VanderPlas, Python Data Science Handbook, O'Reilly Media, 2016. [Online]. Tersedia: https://jakevdp.github.io/PythonDataScienceHandbook/ [Diakses: 18 Sep. 2026].
#
# [4] P. Deitel and H. Deitel, Python for Programmers, Pearson, 2019. [Online]. Tersedia: https://www.pearson.com/ [Diakses: 18 Sep. 2026].
